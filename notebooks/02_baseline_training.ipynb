# %%
import sys
import os

# --- This is the fix ---
# Get the current directory of the notebook
notebook_dir = os.getcwd()
print(f"Current notebook directory: {notebook_dir}")

# Go up one level to the project's root directory
project_root = os.path.abspath(os.path.join(notebook_dir, '..'))
print(f"Project root directory: {project_root}")

# Add the project root to the list of paths Python searches
if project_root not in sys.path:
    sys.path.append(project_root)
    print(" > Successfully added project root to the Python path.")
# -----------------------

# Now, the original imports should work
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from src.models.baseline_lstm import BaselineLSTM
# Out:
# Current notebook directory: C:\stock_prediction_system\notebooks
# Project root directory: C:\stock_prediction_system
